# %% [markdown]
# # Imports

# %%
from glob import glob
import shutil
import os

# %% [markdown]
# # Create groups of 64 slices

# %%
in_path = 'C:/Users/User/Downloads/Liver/labels'
out_path = 'C:/Users/User/Downloads/Liver/dicom_groups/labels'

# %%
# glob --> creates the list of directories also handling Unix code
for patient in glob(in_path + '/*'):
    print(patient)
# Out:
# C:/Users/User/Downloads/Liver/labels\liver_0
# C:/Users/User/Downloads/Liver/labels\liver_1
# C:/Users/User/Downloads/Liver/labels\liver_10
# C:/Users/User/Downloads/Liver/labels\liver_11
# C:/Users/User/Downloads/Liver/labels\liver_12
# C:/Users/User/Downloads/Liver/labels\liver_13
# C:/Users/User/Downloads/Liver/labels\liver_14
# C:/Users/User/Downloads/Liver/labels\liver_15
# C:/Users/User/Downloads/Liver/labels\liver_16
# C:/Users/User/Downloads/Liver/labels\liver_17
# C:/Users/User/Downloads/Liver/labels\liver_18
# C:/Users/User/Downloads/Liver/labels\liver_19
# C:/Users/User/Downloads/Liver/labels\liver_2
# C:/Users/User/Downloads/Liver/labels\liver_20
# C:/Users/User/Downloads/Liver/labels\liver_21
# C:/Users/User/Downloads/Liver/labels\liver_22
# C:/Users/User/Downloads/Liver/labels\liver_23
# C:/Users/User/Downloads/Liver/labels\liver_24
# C:/Users/User/Downloads/Liver/labels\liver_25
# C:/Users/User/Downloads/Liver/labels\liver_26
# C:/Users/User/Downloads/Liver/labels\liver_27
# C:/Users/User/Downloads/Liver/labels\liver_28
# C:/Users/User/Downloads/Liver/labels\liver_29
# C:/Users/User/Downloads/Liver/labels\liver_3
# C:/Users/User/Downloads/Liver/labels\liver_30
# C:/Users/User/Downloads/Liver/labels\liver_31
# C:/Users/User/Downloads/Liver/labels\liver_32
# C:/Users/User/Downloads/Liver/labels\liver_33
# C:/Users/User/Downloads/Liver/labels\liver_34
# C:/Users/User/Downloads/Liver/labels\liver_35
# C:/Users/User/Downloads/Liver/labels\liver_36
# C:/Users/User/Downloads/Liver/labels\liver_37
# C:/Users/User/Downloads/Liver/labels\liver_38
# C:/Users/User/Downloads/Liver/labels\liver_39
# C:/Users/User/Downloads/Liver/labels\liver_4
# C:/Users/User/Downloads/Liver/labels\liver_40
# C:/Users/User/Downloads/Liver/labels\liver_5
# C:/Users/User/Downloads/Liver/labels\liver_6
# C:/Users/User/Downloads/Liver/labels\liver_7
# C:/Users/User/Downloads/Liver/labels\liver_8
# C:/Users/User/Downloads/Liver/labels\liver_9

# %%
for patient in glob(in_path + '/*'):
    patient_name = os.path.basename(os.path.normpath(patient)) 
    number_folders = int(len(glob(patient+'/*'))/64) # number of folders required to group 64 for each patient

    for i in range(number_folders):
        output_path_name = os.path.join(out_path, patient_name + '_' + str(i))
        os.mkdir(output_path_name)
        for j, file in enumerate(glob(patient+'/*')):
            if j == 64:
                break
            shutil.move(file, output_path_name)

# %% [markdown]
# # 64 slices of images

# %%
in_path = 'C:/Users/User/Downloads/Liver/images'
out_path = 'C:/Users/User/Downloads/Liver/dicom_groups/images'

# %%
for patient in glob(in_path + '/*'):
    patient_name = os.path.basename(os.path.normpath(patient)) 
    number_folders = int(len(glob(patient+'/*'))/64) # number of folders required to group 64 for each patient

    for i in range(number_folders):
        output_path_name = os.path.join(out_path, patient_name + '_' + str(i))
        os.mkdir(output_path_name)
        for j, file in enumerate(glob(patient+'/*')):
            if j == 64:
                break
            shutil.move(file, output_path_name)

# %% [markdown]
# # Convert DICOM to NIfTI

# %%
import dicom2nifti

# %%
in_path_images = 'C:/Users/User/Downloads/Liver/dicom_groups/images/*'
in_path_labels = 'C:/Users/User/Downloads/Liver/dicom_groups/labels/*'

out_path_images = 'C:/Users/User/Downloads/Liver/nifti_files/images'
out_path_labels = 'C:/Users/User/Downloads/Liver/nifti_files/labels'

list_images = glob(in_path_images)
list_labels = glob(in_path_labels)

# %%
for patient in list_images:
    patient_name = os.path.basename(os.path.normpath(patient))
    dicom2nifti.dicom_series_to_nifti(patient, os.path.join(out_path_images, patient_name + '.nii.gz'))

# %%
for patient in list_labels:
    patient_name = os.path.basename(os.path.normpath(patient))
    dicom2nifti.dicom_series_to_nifti(patient, os.path.join(out_path_labels, patient_name + '.nii.gz'))

# %% [markdown]
# # Find empty

# %%
import nibabel as nib
import numpy as np

# %%
input_nifti_file_path = 'C:/Users/User/Downloads/Liver/nifti_files/labels/*'
list_nifti_labels = glob(input_nifti_file_path)

for patient in list_nifti_labels:
    nifti_file = nib.load(patient)
    fdata = nifti_file.get_fdata() # retrieves the image data as a NumPy array, here, 64 slides
    np_unique = np.unique(fdata) # Find the unique value in array 
    print(np_unique)
    if len(np_unique) == 1: # if only 0 in the array --> empty image
        print(patient)
# Out:
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_10_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_10_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_10_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_10_3.nii.gz
# [0. 1.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_11_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_11_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_11_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_11_3.nii.gz
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_12_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_12_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_12_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_12_3.nii.gz
# [0. 1.]
# [0. 1.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_13_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_13_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_13_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_13_3.nii.gz
# [0. 1.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_13_7.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_13_8.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_14_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_14_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_14_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_14_3.nii.gz
# [0. 1.]
# [0. 1. 2.]
# [0. 1.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_14_7.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_14_8.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_15_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_15_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_15_2.nii.gz
# [0. 1.]
# [0. 1.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_15_6.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_15_7.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_16_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_16_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_16_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_16_3.nii.gz
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_16_8.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_16_9.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_10.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_11.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_3.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_4.nii.gz
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1.]
# [0. 1.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_9.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_10.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_11.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_12.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_3.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_4.nii.gz
# [0. 1.]
# [0. 1. 2.]
# [0. 1.]
# [0. 1.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_9.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_19_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_19_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_19_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_19_3.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_19_4.nii.gz
# [0. 1.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_20_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_20_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_20_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_20_3.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_20_4.nii.gz
# [0. 1.]
# [0. 1.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_21_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_21_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_21_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_21_3.nii.gz
# [0. 1.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_22_0.nii.gz
# [0. 1. 2.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_23_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_23_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_23_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_23_3.nii.gz
# [0. 1.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_24_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_24_1.nii.gz
# [0. 1.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_25_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_25_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_25_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_25_3.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_25_4.nii.gz
# [0. 1.]
# [0. 1.]
# [0. 1.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_26_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_26_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_26_2.nii.gz
# [0. 1.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_26_7.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_26_8.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_26_9.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_10.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_11.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_12.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_3.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_4.nii.gz
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_9.nii.gz
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_2_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_2_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_2_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_2_3.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_2_4.nii.gz
# [0. 1.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1.]
# [0. 1.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1.]
# [0. 1.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1.]
# [0. 1.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1.]
# [0. 1.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_3_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_3_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_3_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_3_3.nii.gz
# [0. 1.]
# [0. 1. 2.]
# [0. 1.]
# [0. 1.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_10.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_11.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_12.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_3.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_4.nii.gz
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_5_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_5_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_5_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_5_3.nii.gz
# [0. 1.]
# [0. 1.]
# [0. 1.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_6_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_6_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_6_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_6_3.nii.gz
# [0. 1.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_7_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_7_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_7_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_7_3.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_7_4.nii.gz
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_8_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_8_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_8_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_8_3.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_8_4.nii.gz
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_9_0.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_9_1.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_9_2.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_9_3.nii.gz
# [0.]
# C:/Users/User/Downloads/Liver/nifti_files/labels\liver_9_4.nii.gz
# [0. 1. 2.]
# [0. 1. 2.]
# [0. 1. 2.]

# %%
# Deleting empty images, labels
input_nifti_label_path = 'C:/Users/User/Downloads/Liver/nifti_files/labels/*'
list_nifti_labels = glob(input_nifti_label_path)

input_nifti_image_path = 'C:/Users/User/Downloads/Liver/nifti_files/images/'

for patient in list_nifti_labels:
    nifti_file = nib.load(patient)
    fdata = nifti_file.get_fdata() # retrieves the image data as a NumPy array, here, 64 slides
    np_unique = np.unique(fdata) # Find the unique value in array 
    if len(np_unique) == 1: # if only 0 in the array --> empty image
        # If the NIfTI file has only one unique value, delete it.
        os.remove(patient)
        print(f"Deleted NIfTI file label: {patient}")
        
        # And delete it's corresponding image file
        image_name = os.path.basename(patient)
        os.remove(os.path.join(input_nifti_image_path, image_name))
        print(f"Deleted corresponding image: {os.path.join(input_nifti_image_path, image_name)}")
# Out:
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_10_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_10_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_10_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_10_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_10_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_10_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_10_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_10_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_11_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_11_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_11_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_11_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_11_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_11_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_11_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_11_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_12_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_12_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_12_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_12_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_12_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_12_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_12_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_12_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_13_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_13_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_13_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_13_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_13_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_13_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_13_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_13_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_13_7.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_13_7.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_13_8.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_13_8.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_14_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_14_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_14_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_14_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_14_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_14_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_14_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_14_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_14_7.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_14_7.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_14_8.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_14_8.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_15_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_15_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_15_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_15_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_15_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_15_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_15_6.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_15_6.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_15_7.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_15_7.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_16_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_16_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_16_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_16_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_16_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_16_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_16_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_16_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_16_8.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_16_8.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_16_9.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_16_9.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_17_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_17_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_10.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_17_10.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_11.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_17_11.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_17_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_17_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_4.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_17_4.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_17_9.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_17_9.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_18_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_18_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_10.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_18_10.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_11.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_18_11.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_12.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_18_12.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_18_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_18_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_4.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_18_4.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_18_9.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_18_9.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_19_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_19_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_19_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_19_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_19_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_19_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_19_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_19_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_19_4.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_19_4.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_20_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_20_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_20_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_20_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_20_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_20_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_20_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_20_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_20_4.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_20_4.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_21_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_21_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_21_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_21_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_21_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_21_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_21_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_21_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_22_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_22_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_23_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_23_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_23_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_23_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_23_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_23_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_23_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_23_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_24_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_24_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_24_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_24_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_25_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_25_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_25_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_25_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_25_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_25_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_25_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_25_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_25_4.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_25_4.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_26_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_26_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_26_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_26_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_26_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_26_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_26_7.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_26_7.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_26_8.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_26_8.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_26_9.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_26_9.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_27_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_27_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_10.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_27_10.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_11.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_27_11.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_12.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_27_12.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_27_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_27_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_4.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_27_4.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_27_9.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_27_9.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_2_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_2_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_2_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_2_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_2_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_2_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_2_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_2_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_2_4.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_2_4.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_3_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_3_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_3_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_3_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_3_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_3_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_3_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_3_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_4_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_4_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_10.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_4_10.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_11.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_4_11.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_12.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_4_12.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_4_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_4_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_4_4.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_4_4.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_5_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_5_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_5_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_5_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_5_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_5_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_5_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_5_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_6_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_6_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_6_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_6_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_6_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_6_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_6_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_6_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_7_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_7_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_7_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_7_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_7_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_7_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_7_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_7_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_7_4.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_7_4.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_8_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_8_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_8_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_8_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_8_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_8_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_8_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_8_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_8_4.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_8_4.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_9_0.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_9_0.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_9_1.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_9_1.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_9_2.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_9_2.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_9_3.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_9_3.nii.gz
# Deleted NIfTI file label: C:/Users/User/Downloads/Liver/nifti_files/labels\liver_9_4.nii.gz
# Deleted corresponding image: C:/Users/User/Downloads/Liver/nifti_files/images/liver_9_4.nii.gz
